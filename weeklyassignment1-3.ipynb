# %%
import seaborn as sns 
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
import numpy as np
import math
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import math
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
steps = pd.read_csv('steps.csv',sep=";")
steps.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  4-5-2014  5-5-2014  6-5-2014  \
# 0     9929.0    12879.0    10541.0  ...       NaN       NaN       NaN
# 1     4024.0     3926.0    14595.0  ...       NaN       NaN       NaN
# 2     8185.0     9630.0     8983.0  ...    3914.0    4364.0       NaN
# 3        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 4        NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#    7-5-2014  8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014
# ...

# %%
survey = pd.read_csv('survey.csv')
survey.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight
# 0   178.0    98.0
# 1   180.0    77.0
# 2   180.0    83.0
# 3   178.0    80.0
# 4   167.0    61.0

# %%
df = pd.merge(steps,survey, on = 'id') #'id' is the common identifier
df.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  12-5-2014  13-5-2014         city  \
# 0     9929.0    12879.0    10541.0  ...        NaN        NaN     Bordeaux
# 1     4024.0     3926.0    14595.0  ...        NaN        NaN        Lille
# 2     8185.0     9630.0     8983.0  ...     1129.0        NaN  Montpellier
# 3        NaN        NaN        NaN  ...        NaN        NaN         Lyon
# 4        NaN        NaN        NaN  ...        NaN        NaN  Montpellier
#
#    gender    age  hh_size  education          education_1  height  weight
# ...

# %%
def clean_weight(x):
    if x > 200.0 or x < 50.0: 
        return float('NaN')
    else: 
        return x
df['height'] = df['height'].apply(clean_weight)

df.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  12-5-2014  13-5-2014         city  \
# 0     9929.0    12879.0    10541.0  ...        NaN        NaN     Bordeaux
# 1     4024.0     3926.0    14595.0  ...        NaN        NaN        Lille
# 2     8185.0     9630.0     8983.0  ...     1129.0        NaN  Montpellier
# 3        NaN        NaN        NaN  ...        NaN        NaN         Lyon
# 4        NaN        NaN        NaN  ...        NaN        NaN  Montpellier
#
#    gender    age  hh_size  education          education_1  height  weight
# ...

# %%
def clean_height(x):
    if x > 200.0 or x < 40.0: 
        return float('NaN')
    else: 
        return x
df['weight'] = df['weight'].apply(clean_weight)

df.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  12-5-2014  13-5-2014         city  \
# 0     9929.0    12879.0    10541.0  ...        NaN        NaN     Bordeaux
# 1     4024.0     3926.0    14595.0  ...        NaN        NaN        Lille
# 2     8185.0     9630.0     8983.0  ...     1129.0        NaN  Montpellier
# 3        NaN        NaN        NaN  ...        NaN        NaN         Lyon
# 4        NaN        NaN        NaN  ...        NaN        NaN  Montpellier
#
#    gender    age  hh_size  education          education_1  height  weight
# ...

# %%
df['avrage_of_steps'] = df.iloc[:328].mean(axis=1)
df.head()
# Out:
# /var/folders/cc/rk80k3w16x79by01b8m8yk1h0000gn/T/ipykernel_67640/138635626.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['avrage_of_steps'] = df.iloc[:328].mean(axis=1)
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  13-5-2014         city  gender  \
# 0     9929.0    12879.0    10541.0  ...        NaN     Bordeaux    Male
# ...

# %%
df.describe()
# Out:
#                id     20-6-2013     21-6-2013     22-6-2013     23-6-2013  \
# count  929.000000     24.000000    243.000000    278.000000    296.000000
# mean   465.000000   3642.416667   9034.724280  10889.636691   7402.847973
# std    268.323499   3951.910368   6412.774483   6283.204309   6733.291773
# min      1.000000    164.000000     67.000000     25.000000     43.000000
# 25%    233.000000    299.500000   4395.500000   6524.250000   2726.750000
# 50%    465.000000    834.000000   8561.000000   9980.000000   5652.000000
# 75%    697.000000   6060.000000  12182.000000  14338.750000  10472.750000
# max    929.000000  11157.000000  44944.000000  39165.000000  40392.000000
#
#           24-6-2013     25-6-2013     26-6-2013     27-6-2013     28-6-2013  \
# count    354.000000    353.000000    328.000000    380.000000    419.000000
# mean    8110.370056   8690.810198   8362.570122   8261.913158   9231.391408
# ...

# %%
sns.distplot(df['avrage_of_steps'], rug=True)
plt.title('mean steps of all the participants')
plt.xlabel('mean steps')
plt.ylabel('Proportion')
plt.show()
# Out:
# /var/folders/cc/rk80k3w16x79by01b8m8yk1h0000gn/T/ipykernel_67640/1299226577.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['avrage_of_steps'], rug=True)

# %% [markdown]
# There appear to be several outliers for the average number of steps. Let's do some data cleaning.

# %%
def clean_steps(x):
    if x > 30000.0 or x < 0: 
        return float('NaN')
    else: 
        return x
df['avrage_of_steps'] = df['avrage_of_steps'].apply(clean_steps)
df['avrage_of_steps'].name = 'avrage_of_steps'
averagesteps = df['avrage_of_steps'].dropna() 
sns.distplot(averagesteps, kde=False) 
plt.title('avrage_of_steps')
plt.show()
# Out:
# /var/folders/cc/rk80k3w16x79by01b8m8yk1h0000gn/T/ipykernel_67640/3894671970.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(averagesteps, kde=False)

# %%
print("Mean of the mean steps inside the dataframe = ",df['avrage_of_steps'].mean())
print("Median of the mean steps inside the dataframe = ",df['avrage_of_steps'].median())
print("Standard deviation of the mean steps inside the dataframe = ",df['avrage_of_steps'].std())
# Out:
# Mean of the mean steps inside the dataframe =  6098.521389859757
# Median of the mean steps inside the dataframe =  5659.503030303031
# Standard deviation of the mean steps inside the dataframe =  3409.763303626438

# %% [markdown]
# Interpretation
# Normality: The distribution appears nearly normal, with the majority of individuals having approximately 6,000 steps.
#
# Variation: there is little variation, the majority of individuals take between 2,000 and 10,000 steps every day.
#
# Modality: there is one peak at 6.000
#
# Skewness: the distribution is skewed to the right.
#
# Outliers: there are a some outliers (more than 30.000 steps that were cleaned!)

# %%
df['avrage_of_steps'].name = 'avrage_of_steps' 
avr_of_steps = df['avrage_of_steps'].dropna()

# %%
sns.distplot(averagesteps)
plt.title('The average of steps proportion!')
plt.ylabel('Proportion')
plt.show()
# Out:
# /var/folders/cc/rk80k3w16x79by01b8m8yk1h0000gn/T/ipykernel_67640/3787373765.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(averagesteps)

# %%
sns.boxplot(data=df, x="avrage_of_steps", y="age")
# Out:
# <AxesSubplot: xlabel='avrage_of_steps', ylabel='age'>

# %% [markdown]
# Interpretation
#
# Normality: Those between the ages of 55 and 64 had the highest average number of daily steps compared to those older than 65.
#
# Variation: There is a significant difference between the older and younger age groups. The middle age group of 35 to 44 has a higher average daily step count than the older age groups (45-54).
#
# Skewness: For the age groups 35 to 44 and 55 to 64, a right-skewed (positive) distribution is observed. The distribution for those aged 45 to 54 is negative (left). Normal distribution applies to the remaining age groups.
#
# Outliers: This graph contains a few of outliers. In the age range of 25 to 34 years, the point at around 57,500 steps is the most crucial. In addition, there is a notable outlier in the under-25 age range who takes more than 30,000 steps each day.

# %%
df_sel = df[['avrage_of_steps', 'height', 'weight']]

sns.pairplot(df_sel)
plt.show()

# %% [markdown]
# Interpretation
#
# There appears to be a strong linear relationship between the average number of steps and both height and weight. We'll examine the pricing row in both tables and check:

# %% [markdown]
# #### Correlation Matrix

# %%
corr = df[['avrage_of_steps', 'height', 'weight']].corr()
corr
# Out:
#                  avrage_of_steps    height    weight
# avrage_of_steps         1.000000 -0.087674 -0.031641
# height                 -0.087674  1.000000  0.476915
# weight                 -0.031641  0.476915  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap="YlGnBu") #the last two arguments set the column names
plt.show()

# %%
sns.lmplot(x='weight', y='avrage_of_steps', fit_reg=True, data=df, scatter_kws={'alpha':0.1})
plt.xlabel('weight (kg)')
plt.ylabel('average_of_steps')
plt.title('Weight & Average of steps')
plt.show()

# %%
sns.lmplot(x='height', y='avrage_of_steps', fit_reg=True, data=df, scatter_kws={'alpha':0.1}) 
plt.xlabel('height (cm)') 
plt.ylabel('average_of_steps')
plt.title('height & Average of steps')
plt.show()

# %% [markdown]
# #### Interpretation
#
# Clearly, there are relationships between height and average steps and also between weight and average steps.

# %%
df.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  13-5-2014         city  gender  \
# 0     9929.0    12879.0    10541.0  ...        NaN     Bordeaux    Male
# 1     4024.0     3926.0    14595.0  ...        NaN        Lille    Male
# 2     8185.0     9630.0     8983.0  ...        NaN  Montpellier    Male
# 3        NaN        NaN        NaN  ...        NaN         Lyon    Male
# 4        NaN        NaN        NaN  ...        NaN  Montpellier  Female
#
#      age  hh_size  education          education_1  height  weight  \
# ...

# %% [markdown]
# Let's look at the row for average of steps and check..
#
# -if the relationship is linear
# -if there is positive or negative correlation
#
# The variables height, weight will be taken
#
# There appears to be a negative correlation between the average number of steps and height. There appears to be a negative correlation between average of steps and weight.
#
# There is no reason in comparing  weight and height.

# %%
df=df[df['weight'].notna()]

# %%
df=df[df['avrage_of_steps'].notna()]

# %%
from sklearn.linear_model import LinearRegression 

x = df[['weight']] #to use sk-learn, we need to create lists of the two variables
y = df['avrage_of_steps']

lm = LinearRegression() #creating a new LR model
lm.fit(x, y) 

b0 = lm.intercept_ 
b1 = lm.coef_[0]

print(f"The regression line is equal to y = {b0:.2f} + {b1:.2f}X")
# Out:
# The regression line is equal to y = 6573.14 + -7.06X

# %% [markdown]
# Or, in a pretty Markdown formula (using $ to begin and end a formula):
#
# y = 6573.14 + -7.06X Where y is average of steps and x is wight .
#
# Now, let's use our model to predict the values in our dataset:

# %%
df['avrage_of_steps_p'] = lm.predict(x) 
df.head(50)
# Out:
#     id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0    1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1    2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2    3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3    4        NaN        NaN        NaN        NaN        NaN        NaN
# 4    5        NaN        NaN        NaN        NaN        NaN        NaN
# 5    6        NaN    16924.0    14411.0     5121.0    29784.0     8995.0
# 6    7        NaN        NaN        NaN        NaN        NaN        NaN
# 7    8        NaN        NaN        NaN        NaN        NaN        NaN
# 8    9        NaN        NaN        NaN        NaN        NaN        NaN
# 9   10        NaN        NaN        NaN        NaN        NaN        NaN
# 10  11        NaN        NaN        NaN        NaN        NaN        NaN
# 11  12        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
df["resid"] = df["avrage_of_steps"] - df['avrage_of_steps_p']
df.head(20)
# Out:
#     id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0    1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1    2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2    3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3    4        NaN        NaN        NaN        NaN        NaN        NaN
# 4    5        NaN        NaN        NaN        NaN        NaN        NaN
# 5    6        NaN    16924.0    14411.0     5121.0    29784.0     8995.0
# 6    7        NaN        NaN        NaN        NaN        NaN        NaN
# 7    8        NaN        NaN        NaN        NaN        NaN        NaN
# 8    9        NaN        NaN        NaN        NaN        NaN        NaN
# 9   10        NaN        NaN        NaN        NaN        NaN        NaN
# 10  11        NaN        NaN        NaN        NaN        NaN        NaN
# 11  12        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
df=df[df['gender'].notna()]
dummies = pd.get_dummies(df["gender"])
dummies
# Out:
#      Female  Male
# 0         0     1
# 1         0     1
# 2         0     1
# 3         0     1
# 4         1     0
# ..      ...   ...
# 323       1     0
# 324       1     0
# 325       0     1
# 326       0     1
# 327       0     1
#
# [312 rows x 2 columns]

# %%
df = pd.concat([df, dummies], axis=1) #add to dataframe
df.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  hh_size  education  \
# 0     9929.0    12879.0    10541.0  ...        4          4
# 1     4024.0     3926.0    14595.0  ...        1          3
# 2     8185.0     9630.0     8983.0  ...        2          2
# 3        NaN        NaN        NaN  ...        1          1
# 4        NaN        NaN        NaN  ...        3          4
#
#            education_1  height  weight  avrage_of_steps  avrage_of_steps_p  \
# 0  Master or doctorate   178.0    98.0      9907.035294        5881.203058
# ...

# %% [markdown]
# #### Multiple linear regression

# %%
df=df[df['height'].notna()]
df=df[df['weight'].notna()]
df=df[df['Male'].notna()]
df=df[df['Female'].notna()]
X = df[['height', 'weight','Male','Female']] 
y = df['avrage_of_steps']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) #split the data, store it into different variables
X_train.head() #The train data

lm = LinearRegression() #this creates a new LR model
lm.fit(X_train, y_train) #this "fits" the model on the training data
# Out:
# LinearRegression()

# %%
y_test_p = lm.predict(X_test) #use built-in predict() method to generate predictions; store in original dataframe

# %% [markdown]
# #### Evaluating the model

# %%
sns.scatterplot(x=y_test,y=y_test_p)
plt.xlim(0, 10000) #This sets the x-axis limits to (0, 5e10 = 140000000000)
plt.ylim(0, 10000) #same for y-axis. 
plt.plot([0, 10000], [0, 10000], color='red', lw=3) 
plt.xlabel('avrage_of_steps')
plt.ylabel('avrage_of_steps_predicted')
plt.show()

# %% [markdown]
# On x-axis the actual average of steps are visible. On the y-axis the predicted average for that channel is visible. If the model would work perfectly, all points should be on the line. Clearly, they are not.
#
# We can conclude that the model works poorly.
#
# Now to predict the R^2 and RMSE

# %%
r2_score(df['avrage_of_steps'], df['avrage_of_steps_p']) #this gives the model fit (R2) for the Y and predicted Y
# Out:
# 0.000942544241847032

# %% [markdown]
# The R^2 is 0.00094, which means that only 0.094% of the variation in steps is explained by the model. That's really low.

# %%
math.sqrt(mean_squared_error(df['avrage_of_steps'], df['avrage_of_steps_p'])) #this gives the model fit (R2) for the Y and predicted Y
# Out:
# 3372.432578659501

# %% [markdown]
# The RMSE is 3372.4 steps. Which means that we are typically about 3372.4 steps off in our predicted views.
